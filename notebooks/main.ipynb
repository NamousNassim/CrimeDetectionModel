# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import xgboost as xgb
import torch
import torch.nn as nn
import torch.optim as optim

# %%
path = '../data/Crimes_-_2022.csv'

df = pd.read_csv(path)

df.sample(5)
# Out:
#               ID Case Number                    Date               Block  \
# 181413  12898892    JF481939  11/20/2022 07:45:00 AM  106XX S RHODES AVE
# 96394   12657819    JF192306  03/30/2022 03:00:00 PM  087XX S LUELLA AVE
# 165976  12712282    JF257229  05/27/2022 03:30:00 AM  002XX S CICERO AVE
# 188917  12870899    JF448529  10/24/2022 04:25:00 PM     026XX E 81ST ST
# 52670   12725425    JF274190  06/10/2022 08:27:00 AM     030XX W 61ST ST
#
#         IUCR         Primary Type  \
# 181413  1220   DECEPTIVE PRACTICE
# 96394   0910  MOTOR VEHICLE THEFT
# 165976  0910  MOTOR VEHICLE THEFT
# 188917  0820                THEFT
# 52670   0497              BATTERY
#
#                                               Description  \
# 181413                   THEFT OF LOST / MISLAID PROPERTY
# 96394                                          AUTOMOBILE
# 165976                                         AUTOMOBILE
# 188917                                     $500 AND UNDER
# 52670   AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS ...
#
#                           Location Description  Arrest  Domestic  ...  Ward  \
# 181413                                  STREET   False     False  ...   9.0
# 96394                                   STREET   False     False  ...   8.0
# 165976  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...  28.0
# 188917             RESIDENCE - PORCH / HALLWAY   False     False  ...   7.0
# 52670                                APARTMENT   False      True  ...  16.0
#
#         Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 181413              49        11     1181796.0    1834535.0  2022
# 96394               48        07     1192686.0    1847483.0  2022
# 165976              25        07     1144430.0    1898404.0  2022
# 188917              46        06     1195361.0    1851778.0  2022
# 52670               66       04B     1157307.0    1864036.0  2022
#
#                     Updated On   Latitude  Longitude  \
# 181413  01/03/2023 03:40:27 PM  41.701190 -87.609938
# 96394   01/03/2023 03:40:27 PM  41.736463 -87.569642
# 165976  01/03/2023 03:40:27 PM  41.877237 -87.745161
# 188917  01/03/2023 03:40:27 PM  41.748183 -87.559701
# 52670   01/03/2023 03:40:27 PM  41.782675 -87.698812
#
#                              Location
# 181413  (41.701190145, -87.609937617)
# 96394   (41.736462812, -87.569642178)
# 165976  (41.877237033, -87.745160873)
# 188917  (41.748183087, -87.559700606)
# 52670   (41.782675195, -87.698811963)
#
# [5 rows x 22 columns]
